# %%
from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtGui import QPalette, QBrush, QPixmap, QPainter
from PyQt5.QtCore import pyqtSignal, QObject
import sys

# %%
usage = ["Вирусологические исследования", "Иммуноферментный анализ (ИФА)", "Микробиологические исследования",\
         "Молекулярно-биологические исследования", "Расходные материалы для вирусологических, молекулярно-биологических и иммуноферментных исследований",\
         "Санитарно-химические и физико-химические исследования"]
objects = ["Биологический (клинический) материал", "Вода", "Воздух", "Непродовольственная продукция", "Пищевые продукты", "Почва", "Смывы"]
sub_1, sub_2, sub_3, sub_4 = [], [], [], []
materials = []
units = ['мг', 'г', 'кг', 'мл', 'л', 'шт']

# %%
class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(647, 760)
        MainWindow.setFocusPolicy(QtCore.Qt.WheelFocus)
        MainWindow.setContextMenuPolicy(QtCore.Qt.DefaultContextMenu)
        MainWindow.setDocumentMode(False)
        MainWindow.setTabShape(QtWidgets.QTabWidget.Rounded)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.lineEdit = QtWidgets.QLineEdit(self.centralwidget)
        self.lineEdit.setGeometry(QtCore.QRect(20, 50, 590, 20))
        self.lineEdit.setObjectName("lineEdit")
        self.label = QtWidgets.QLabel(self.centralwidget)
        self.label.setGeometry(QtCore.QRect(10, 30, 271, 20))
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.centralwidget)
        self.label_2.setGeometry(QtCore.QRect(10, 80, 271, 20))
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(self.centralwidget)
        self.label_3.setGeometry(QtCore.QRect(10, 150, 271, 20))
        self.label_3.setObjectName("label_3")
        
        self.comboBox = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox.setGeometry(QtCore.QRect(20, 110, 261, 22))
        self.comboBox.setObjectName("comboBox")
        self.comboBox.addItems(usage)
        
        self.comboBox_2 = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox_2.setGeometry(QtCore.QRect(20, 170, 261, 22))
        self.comboBox_2.setObjectName("comboBox_2")
        self.comboBox_2.addItems(objects)
        
        self.label_8 = QtWidgets.QLabel(self.centralwidget)
        self.label_8.setGeometry(QtCore.QRect(10, 210, 271, 20))
        self.label_8.setObjectName("label_8")
        
        self.comboBox_7 = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox_7.setGeometry(QtCore.QRect(20, 230, 261, 22))
        self.comboBox_7.setObjectName("comboBox_7")
        self.comboBox_7.addItems(materials)
        
        self.label_9 = QtWidgets.QLabel(self.centralwidget)
        self.label_9.setGeometry(QtCore.QRect(10, 270, 271, 20))
        self.label_9.setObjectName("label_9")
        
        self.comboBox_8 = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox_8.setGeometry(QtCore.QRect(20, 290, 261, 22))
        self.comboBox_8.setObjectName("comboBox_8")
        self.comboBox_8.addItems(units)
        
        self.label_10 = QtWidgets.QLabel(self.centralwidget)
        self.label_10.setGeometry(QtCore.QRect(10, 330, 271, 20))
        self.label_10.setObjectName("label_10")
        
        self.doubleSpinBox_month = QtWidgets.QDoubleSpinBox(self.centralwidget)
        self.doubleSpinBox_month.setGeometry(QtCore.QRect(20, 350, 261, 21))
        self.doubleSpinBox_month.setObjectName('spinBox_month')
        self.doubleSpinBox_month.setMaximum(10000.999)
        
        self.doubleSpinBox_year = QtWidgets.QDoubleSpinBox(self.centralwidget)
        self.doubleSpinBox_year.setGeometry(QtCore.QRect(20, 400, 261, 21))
        self.doubleSpinBox_year.setObjectName('spinBox_year')
        self.doubleSpinBox_year.setMaximum(9999999)
        
        self.label_11 = QtWidgets.QLabel(self.centralwidget)
        self.label_11.setGeometry(QtCore.QRect(10, 380, 271, 20))
        self.label_11.setObjectName("label_11")
        
        self.doubleSpinBox_available = QtWidgets.QDoubleSpinBox(self.centralwidget)
        self.doubleSpinBox_available.setGeometry(QtCore.QRect(20, 450, 261, 21))
        self.doubleSpinBox_available.setObjectName('spinBox_available')
        self.doubleSpinBox_available.setMaximum(9999999)
#########################################################################        
        self.label_sub_1 = QtWidgets.QLabel(self.centralwidget)
        self.label_sub_1.setEnabled(False)
        self.label_sub_1.setGeometry(QtCore.QRect(340, 90, 271, 20))
        self.label_sub_1.setText('Подргуппа 1')
        self.label_sub_1.setObjectName("label_sub_1")
        
        self.comboBox_sub_1 = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox_sub_1.setEnabled(False)
        self.comboBox_sub_1.setGeometry(QtCore.QRect(350, 110, 261, 22))
        self.comboBox_sub_1.setObjectName("comboBox_sub_1")
        self.comboBox_sub_1.addItems(sub_1)
        
        self.comboBox_sub_2 = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox_sub_2.setEnabled(False)
        self.comboBox_sub_2.setGeometry(QtCore.QRect(350, 170, 261, 22))
        self.comboBox_sub_2.setObjectName("comboBox_sub_2")
        self.comboBox_sub_2.addItems(sub_2)
        
        self.label_sub_2 = QtWidgets.QLabel(self.centralwidget)
        self.label_sub_2.setEnabled(False)
        self.label_sub_2.setGeometry(QtCore.QRect(340, 150, 271, 20))
        self.label_sub_2.setText('Подргуппа 2')
        self.label_sub_2.setObjectName("label_sub_2")
        
        self.comboBox_sub_3 = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox_sub_3.setEnabled(False)
        self.comboBox_sub_3.setGeometry(QtCore.QRect(350, 230, 261, 22))
        self.comboBox_sub_3.setObjectName("comboBox_sub_3")
        self.comboBox_sub_3.addItems(sub_3)
        
        self.label_sub_3 = QtWidgets.QLabel(self.centralwidget)
        self.label_sub_3.setEnabled(False)
        self.label_sub_3.setGeometry(QtCore.QRect(340, 210, 271, 20))
        self.label_sub_3.setText('Подргуппа 3')
        self.label_sub_3.setObjectName("label_sub_3")
        
        self.label_sub_4 = QtWidgets.QLabel(self.centralwidget)
        self.label_sub_4.setEnabled(False)
        self.label_sub_4.setGeometry(QtCore.QRect(340, 270, 261, 20))
        self.label_sub_4.setText('Подргуппа 4')
        self.label_sub_4.setObjectName("label_sub_4")
        
        self.comboBox_sub_4 = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox_sub_4.setEnabled(False)
        self.comboBox_sub_4.setGeometry(QtCore.QRect(350, 290, 261, 22))
        self.comboBox_sub_4.setObjectName("comboBox_sub_4")
        self.comboBox_sub_4.addItems(sub_4)       
##########################################################################        
        self.label_12 = QtWidgets.QLabel(self.centralwidget)
        self.label_12.setGeometry(QtCore.QRect(10, 430, 271, 20))
        self.label_12.setObjectName("label_12")
        
        self.checkBox = QtWidgets.QCheckBox(self.centralwidget)
        self.checkBox.setGeometry(QtCore.QRect(350, 350, 261, 21))
        self.checkBox.setObjectName("checkBox")
        
        self.lineEdit_5 = QtWidgets.QLineEdit(self.centralwidget)
        self.lineEdit_5.setEnabled(False)
        self.lineEdit_5.setGeometry(QtCore.QRect(350, 400, 261, 21))
        self.lineEdit_5.setObjectName("lineEdit_5")
        
        self.label_13 = QtWidgets.QLabel(self.centralwidget)
        self.label_13.setEnabled(False)
        self.label_13.setGeometry(QtCore.QRect(340, 380, 271, 20))
        self.label_13.setObjectName("label_13")
        
        self.lineEdit_6 = QtWidgets.QLineEdit(self.centralwidget)
        self.lineEdit_6.setEnabled(False)
        self.lineEdit_6.setGeometry(QtCore.QRect(350, 450, 261, 21))
        self.lineEdit_6.setText("")
        self.lineEdit_6.setObjectName("lineEdit_6")
        
        self.label_14 = QtWidgets.QLabel(self.centralwidget)
        self.label_14.setEnabled(False)
        self.label_14.setGeometry(QtCore.QRect(340, 430, 271, 20))
        self.label_14.setObjectName("label_14")
#######################################################################        
        self.pushButton = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton.setGeometry(QtCore.QRect(180, 500, 251, 31))
        self.pushButton.setAutoDefault(False)
        self.pushButton.setDefault(False)
        self.pushButton.setFlat(False)
        self.pushButton.setObjectName("pushButton")
        
        self.pushButton_2 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_2.setGeometry(QtCore.QRect(200, 570, 211, 21))
        self.pushButton_2.setAutoDefault(False)
        self.pushButton_2.setDefault(False)
        self.pushButton_2.setFlat(False)
        self.pushButton_2.setObjectName("pushButton_3")
        
        self.label_15 = QtWidgets.QLabel(self.centralwidget)
        self.label_15.setEnabled(True)
        self.label_15.setGeometry(QtCore.QRect(220, 590, 191, 21))
        self.label_15.setObjectName("label_15")
        
        self.label_16 = QtWidgets.QLabel(self.centralwidget)
        self.label_16.setGeometry(QtCore.QRect(250, 530, 121, 20))
        self.label_16.setObjectName("label_16")
        
        MainWindow.setCentralWidget(self.centralwidget)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        self.checkBox.clicked.connect(self.lineEdit_5.show)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.label.setText(_translate("MainWindow", "Наименование учреждения"))
        self.label_2.setText(_translate("MainWindow", "Направление использования"))
        self.label_3.setText(_translate("MainWindow", "Объект исследования"))
        self.label_8.setText(_translate("MainWindow", "Наименование расходного материала"))
        self.label_9.setText(_translate("MainWindow", "Единица измерения"))
        self.label_10.setText(_translate("MainWindow", "Потребность на месяц"))
        self.label_11.setText(_translate("MainWindow", "Потребность на год"))
        self.label_12.setText(_translate("MainWindow", "Фактическое наличие"))
        self.checkBox.setText(_translate("MainWindow", "Критичность"))
        self.label_13.setText(_translate("MainWindow", "Показатели (перечислить через запятую)"))
        self.label_14.setText(_translate("MainWindow", "Комментарий"))
        self.pushButton.setText(_translate("MainWindow", "СДЕЛОТЬ КРОСИВО"))
        self.pushButton_2.setText(_translate("MainWindow", "ПЕРЕЙТИ К АЧЁТУ"))
        self.label_15.setText(_translate("MainWindow", "Отчёт сначала сделай, додик"))

# %%
class mywindow(QtWidgets.QMainWindow):
    def __init__(self):
        super(mywindow, self).__init__()
        self.ui = Ui_MainWindow()
        self.ui.setupUi(self)
        
        #self.ui.lineEdit.setText('GOVNO MOCHA')
        #self.ui.lineEdit.setReadOnly(True) ###################################################################
        
        self.ui.pushButton.clicked.connect(self.btnClicked) # сделоть кросиво
        self.ui.checkBox.clicked.connect(self.checkboxClicked)
        
#     def paintEvent(self, a0: QtGui.QPaintEvent) -> None:
#         painter = QPainter(self)
#         pixmap = QPixmap("./kover.jpg")
#         painter.drawPixmap(self.rect(), pixmap)
    
    def checkboxClicked(self):
        self.ui.lineEdit_5.setEnabled(self.ui.checkBox.checkState())
        self.ui.lineEdit_6.setEnabled(self.ui.checkBox.checkState())
        self.ui.label_13.setEnabled(self.ui.checkBox.checkState())
        self.ui.label_14.setEnabled(self.ui.checkBox.checkState())
        
#     def btnClicked(self): # сделоть кросиво
#         self.ui.label_16.setText('gotovo')
#         print(self.ui.lineEdit.text()) #####
#         print(self.ui.lineEdit_6.text())
#         print(self.ui.doubleSpinBox_month.value())
        
    def btnClicked(self):
        print( {
            'name': self.ui.lineEdit.text(),
            'usage':self.ui.comboBox.currentText(),
            'objects':self.ui.comboBox_2.currentText(),
            'materials':self.ui.comboBox_7.currentText(),
            'units':self.ui.comboBox_8.currentText(),
            'sub_1':self.ui.comboBox_sub_1.currentText(),
            'sub_2':self.ui.comboBox_sub_2.currentText(),
            'sub_3':self.ui.comboBox_sub_3.currentText(),
            'sub_4':self.ui.comboBox_sub_4.currentText(),
            'month':self.ui.doubleSpinBox_month.value(),
            'year':self.ui.doubleSpinBox_year.value(),
            'available':self.ui.doubleSpinBox_available.value(),
            'indicators':self.ui.lineEdit_5.text(),
            'comment':self.ui.lineEdit_6.text()
        })
    
app = QtWidgets.QApplication([])
application = mywindow()
application.show()
 
sys.exit(app.exec())
# Out:
# {'name': 'abs', 'usage': 'Вирусологические исследования', 'objects': 'Биологический (клинический) материал', 'materials': '', 'units': 'мг', 'sub_1': '', 'sub_2': '', 'sub_3': '', 'sub_4': '', 'month': 1.0, 'year': 2.0, 'available': 3.0, 'indicators': 'z', 'comment': 'x'}
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\zhilapv\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
